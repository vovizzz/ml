# %% [markdown]
# <a href="https://colab.research.google.com/github/vovizzz/ml/blob/main/6_2_Nykyforov_FIt_4_6.ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.datasets import load_iris
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# 1. Завантаження даних Iris
iris = load_iris()
X = iris.data

# 2. Метод ліктя для визначення оптимальної кількості кластерів
inertia = []
K = range(1, 10)
for k in K:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X)
    inertia.append(kmeans.inertia_)

# Візуалізація методу ліктя
plt.plot(K, inertia, 'bx-')
plt.xlabel('Кількість кластерів')
plt.ylabel('Інерція')
plt.title('Метод ліктя для оптимального k')
plt.show()

# 3. Кластеризація даних з оптимальною кількістю кластерів
optimal_k = 3
kmeans = KMeans(n_clusters=optimal_k, random_state=42)
clusters = kmeans.fit_predict(X)

# Візуалізація кластерів
plt.scatter(X[:, 0], X[:, 1], c=clusters, cmap='viridis')
plt.xlabel('Ознака 1')
plt.ylabel('Ознака 2')
plt.title('Кластеризація методом KMeans')
plt.show()
